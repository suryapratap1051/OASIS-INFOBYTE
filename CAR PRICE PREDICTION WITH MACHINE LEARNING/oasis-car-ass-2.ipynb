# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
car=pd.read_csv("CarPrice.csv")

# %%
car
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
car=car.drop("car_ID",axis=1)

# %%
car
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 0            3        alfa-romero giulia      gas        std        two
# 1            3       alfa-romero stelvio      gas        std        two
# 2            1  alfa-romero Quadrifoglio      gas        std        two
# 3            2               audi 100 ls      gas        std       four
# 4            2                audi 100ls      gas        std       four
# ..         ...                       ...      ...        ...        ...
# 200         -1           volvo 145e (sw)      gas        std       four
# 201         -1               volvo 144ea      gas      turbo       four
# 202         -1               volvo 244dl      gas        std       four
# 203         -1                 volvo 246   diesel      turbo       four
# 204         -1               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   CarName           205 non-null    object
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    object
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    object
#  15  enginesize        205 non-null    int64
# ...

# %%
car.isnull().sum()
# Out:
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
avg=car.mean().round(4)

# %%
car['doornumber'].unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
car['doornumber'].value_counts()
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
car['doornumber']= car['doornumber'].fillna('four')

# %%
car['doornumber']= car['doornumber'].replace({"two":2,"four":4})

# %%
car['doornumber'].unique()
# Out:
# array([2, 4], dtype=int64)

# %%
car['cylindernumber'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
car['cylindernumber']= car['cylindernumber'].replace({'four':4, 'six':6, 'five':5,'three':3, 'twelve':12, 'two':2,'eight':8})

# %%
car['cylindernumber'].unique()
# Out:
# array([ 4,  6,  5,  3, 12,  2,  8], dtype=int64)

# %% [markdown]
# # Data Correletion

# %%
car.corr()
# Out:
#                   symboling  doornumber  wheelbase  carlength  carwidth  \
# symboling          1.000000   -0.664073  -0.531954  -0.357612 -0.232919
# doornumber        -0.664073    1.000000   0.447357   0.398568  0.207168
# wheelbase         -0.531954    0.447357   1.000000   0.874587  0.795144
# carlength         -0.357612    0.398568   0.874587   1.000000  0.841118
# carwidth          -0.232919    0.207168   0.795144   0.841118  1.000000
# carheight         -0.541038    0.552208   0.589435   0.491029  0.279210
# curbweight        -0.227691    0.197379   0.776386   0.877728  0.867032
# cylindernumber    -0.113129   -0.016009   0.339507   0.430672  0.545007
# enginesize        -0.105790    0.020742   0.569329   0.683360  0.735433
# boreratio         -0.130051    0.119258   0.488750   0.606454  0.559150
# stroke            -0.008735   -0.011082   0.160959   0.129533  0.182942
# compressionratio  -0.178515    0.177888   0.249786   0.158414  0.181129
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(car.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Feature Reduction

# %%
car_reduction=car.drop(columns=['carwidth','carlength','wheelbase','enginesize','highwaympg','horsepower','citympg'])

# %%
car_reduction
# Out:
#      symboling                   CarName fueltype aspiration  doornumber  \
# 0            3        alfa-romero giulia      gas        std           2
# 1            3       alfa-romero stelvio      gas        std           2
# 2            1  alfa-romero Quadrifoglio      gas        std           2
# 3            2               audi 100 ls      gas        std           4
# 4            2                audi 100ls      gas        std           4
# ..         ...                       ...      ...        ...         ...
# 200         -1           volvo 145e (sw)      gas        std           4
# 201         -1               volvo 144ea      gas      turbo           4
# 202         -1               volvo 244dl      gas        std           4
# 203         -1                 volvo 246   diesel      turbo           4
# 204         -1               volvo 264gl      gas      turbo           4
#
#          carbody drivewheel enginelocation  carheight  curbweight enginetype  \
# ...

# %% [markdown]
# # Categorical Features transformation

# %%
DFrame = pd.get_dummies(car_reduction, drop_first=True)
DFrame
# Out:
#      symboling  doornumber  carheight  curbweight  cylindernumber  boreratio  \
# 0            3           2       48.8        2548               4       3.47
# 1            3           2       48.8        2548               4       3.47
# 2            1           2       52.4        2823               6       2.68
# 3            2           4       54.3        2337               4       3.19
# 4            2           4       54.3        2824               5       3.19
# ..         ...         ...        ...         ...             ...        ...
# 200         -1           4       55.5        2952               4       3.78
# 201         -1           4       55.5        3049               4       3.78
# 202         -1           4       55.5        3012               6       3.58
# 203         -1           4       55.5        3217               6       3.01
# 204         -1           4       55.5        3062               4       3.78
#
# ...

# %% [markdown]
# # Divide Data

# %%
x=DFrame.drop('price' , axis=1)
y=pd.DataFrame(DFrame['price'])

# %%
x
# Out:
#      symboling  doornumber  carheight  curbweight  cylindernumber  boreratio  \
# 0            3           2       48.8        2548               4       3.47
# 1            3           2       48.8        2548               4       3.47
# 2            1           2       52.4        2823               6       2.68
# 3            2           4       54.3        2337               4       3.19
# 4            2           4       54.3        2824               5       3.19
# ..         ...         ...        ...         ...             ...        ...
# 200         -1           4       55.5        2952               4       3.78
# 201         -1           4       55.5        3049               4       3.78
# 202         -1           4       55.5        3012               6       3.58
# 203         -1           4       55.5        3217               6       3.01
# 204         -1           4       55.5        3062               4       3.78
#
# ...

# %%
y
# Out:
#        price
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# ..       ...
# 200  16845.0
# 201  19045.0
# 202  21485.0
# 203  22470.0
# 204  22625.0
#
# [205 rows x 1 columns]

# %% [markdown]
# # Divid Data into Train & Test

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import PolynomialFeatures, MinMaxScaler

# %%
x_train,x_test ,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)
x_test.head()
# Out:
#      symboling  doornumber  carheight  curbweight  cylindernumber  boreratio  \
# 78           2           2       50.8        2004               4       2.97
# 97           1           4       53.5        2037               4       3.15
# 151          1           2       54.5        2040               4       3.05
# 44           1           2       52.0        1874               4       3.03
# 40           0           4       54.1        2372               4       3.15
#
#      stroke  compressionratio  peakrpm  CarName_alfa-romero Quadrifoglio  ...  \
# 78     3.23               9.4     5500                                 0  ...
# 97     3.29               9.4     5200                                 0  ...
# 151    3.03               9.0     4800                                 0  ...
# 44     3.11               9.6     5400                                 0  ...
# 40     3.58               9.0     5800                                 0  ...
#
# ...

# %%
y_test.head()
# Out:
#        price
# 78    6669.0
# 97    7999.0
# 151   6338.0
# 44    8916.5
# 40   10295.0

# %% [markdown]
# # Numerical Feature Scaling

# %%
scaler_x = MinMaxScaler().fit(x_train)
scaler_y = MinMaxScaler().fit(y_train)

# %%
x_train_sc = scaler_x.transform(x_train)
x_test_sc = scaler_x.transform(x_test)

# %%
y_train_sc = scaler_y.transform(y_train)
y_test_sc = scaler_y.transform(y_test)

# %%
x_train_sc
# Out:
# array([[0.6       , 0.        , 0.15833333, ..., 1.        , 0.        ,
#         0.        ],
#        [0.6       , 0.        , 0.55833333, ..., 0.        , 0.        ,
#         0.        ],
#        [0.4       , 1.        , 0.43333333, ..., 1.        , 0.        ,
#         0.        ],
#        ...,
#        [1.        , 0.        , 0.25      , ..., 1.        , 0.        ,
#         0.        ],
#        [0.8       , 0.        , 0.65833333, ..., 0.        , 0.        ,
#         0.        ],
#        [0.4       , 0.        , 0.45833333, ..., 0.        , 0.        ,
#         0.        ]])

# %%
y_train_sc
# Out:
# array([[0.32841686],
#        [0.04735729],
#        [0.12443726],
#        [0.07461758],
#        [0.06476806],
#        [0.88956597],
#        [0.02238528],
#        [0.3222236 ],
#        [0.20654147],
#        [0.57159557],
#        [0.1667703 ],
#        [0.48178087],
#        [0.10105708],
#        [0.09078473],
#        [0.02735978],
#        [0.15055341],
#        [0.09078473],
#        [0.21552046],
#        [0.0756871 ],
#        [0.16540231],
#        [0.14184803],
#        [0.18826017],
#        [0.26252954],
#        [0.06723044],
#        [0.03730879],
#        [0.0523318 ],
#        [0.1185176 ],
#        [0.36075115],
#        [0.16552668],
#        [0.12809352],
#        [0.78808606],
#        [0.25009327],
#        [0.0038055 ],
#        [0.34212163],
#        [0.7550056 ],
#        [0.10205198],
#        [0.32704887],
#        [0.29548564],
#        [0.05471956],
#        [0.05357543],
#        [0.06004228],
#        [0.00756125],
#        [0.15804004],
# ...

# %% [markdown]
# # Apply Linear Regression¶

# %%
lr_model = LinearRegression()
lr_model.fit(x_train_sc,y_train_sc)
y_pred_sc = lr_model.predict(x_test_sc)

# %% [markdown]
# # Evaluating the model

# %%
mae =mean_absolute_error(y_test_sc,y_pred_sc)
rmse = np.sqrt(mean_squared_error(y_test_sc,y_pred_sc))

print("MAE= ",mae.round(4))
print('RMSE= ',rmse.round(4))
# Out:
# MAE=  490204586609.6812
# RMSE=  889893107396.1664

# %% [markdown]
# # Inverse Transformation of scaling

# %%
y_test_inv = scaler_y.inverse_transform(y_test_sc.reshape(-1,1))
y_pred_inv = scaler_y.inverse_transform(y_pred_sc.reshape(-1,1))

actual_mae = mean_absolute_error(y_test_inv,y_pred_inv)
actual_rmse = np.sqrt(mean_squared_error(y_test_inv,y_pred_inv))

print("Actual MAE= ",actual_mae.round(4))
print('Actual RMSE= ',actual_rmse.round(4))
# Out:
# Actual MAE=  1.9708675404642236e+16
# Actual RMSE=  3.5778152382862864e+16
